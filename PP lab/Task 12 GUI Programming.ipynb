# %% [markdown]
# # GUI Programming

# %%
1. Write a GUI program to create a window wizard having two text
labels, two text/entry fields and three buttons as Submit, Reset, 
and Close.

# %%
Tkinter is a standard Python library for creating Graphical User
Interfaces (GUIs). It provides a set of widgets to design and build 
GUI applications.

# %%
A widget is a graphical element or component that provides a specific visual or interactive function within a user interface. 
Widgets are the building blocks of a GUI and are used to create the various elements users interact with, such as buttons, labels, text entry fields, checkboxes, radiobuttons, menu, and more. 
They are responsible for displaying information, capturing user input, and facilitating user interactions with the application.

# %%
Label: It refers to the display box where you can put any text or
image.

Entry field: It captures the input from the user.

Button: It creates a button. When clicked it performs a specified 
opearation.

# %%
import tkinter as tk
root = tk.Tk()
root.title("Details of the student")
root.geometry("500x500")
root.mainloop()

# %%
import tkinter as tk
# Create the main window
root = tk.Tk()
root.title("Details of the student")
root.geometry("500x500")
# Create labels and entry fields
name_label = tk.Label(root, text="Name:")
name_label.pack()

name_entry = tk.Entry(root)
name_entry.pack()

age_label = tk.Label(root, text="Age:")
age_label.pack()

age_entry = tk.Entry(root)
age_entry.pack()

def submit():
    name = name_entry.get()
    age = age_entry.get()
    print(f"Name: {name}\nAge: {age}")

def reset():
    name_entry.delete(0, tk.END)
    age_entry.delete(0, tk.END)
    
# Create buttons
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()
reset_button = tk.Button(root, text="Reset", command=reset)
reset_button.pack()
close_button = tk.Button(root, text="Close", command=root.destroy)
close_button.pack()

# Run the Tkinter event loop
root.mainloop()
# Out:
# Name: ECE3
# Age: 18

# %%
import tkinter as tk
root = tk.Tk()
root.title("Details of the student")
root.geometry("500x500")

submit_button = tk.Button(root, text="Submit", command=root.destroy)
submit_button.pack()

root.mainloop()
