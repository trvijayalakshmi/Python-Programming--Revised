# %%
Sequence types: Strings, Lists, Tuples

Sequence has an index.

Mapping type: Dictionary

# %% [markdown]
# ### 1. Creation and Accessing Strings

# %% [markdown]
# A string is a sequence of characters enclosed in single ('), double (") or triple quotes (''' / """).

# %%
str1 = 'Hello'
str2 = "Python"
str3 = '''This is 
a multiline string'''

# %% [markdown]
# Indexing - Each character has an index, starting from 0.

# %%
word = "Python"
print(word[0])   # P
print(word[3])   # h
# Out:
# P
# h

# %%
Slicing - Extracting part of the string using [start:end]
(end index is excluded).

# %%
text = "Programming"
print(text[0:6])   # Progra
print(text[3:])    # gramming
print(text[:5])    # Progr
print(text[-3:-6:-1]) # Reverse printing
print(text[-8:-4])
# Out:
# Progra
# gramming
# Progr
# imm
# gram

# %% [markdown]
# ### 2. String Methods - Built-in methods:

# %%
1. Case Conversion

# %%
s = "python programming"
print(s.upper())   # PYTHON PROGRAMMING
print(s.lower())   # python programming
print(s.title())   # Python Programming
print(s.capitalize()) # Python programming

print(len(s))         # 18
# Out:
# PYTHON PROGRAMMING
# python programming
# Python Programming
# Python programming
# 18

# %%
2. Checking Content

# %%
s = "Python123"
print(s.isalpha())   # False (contains numbers)
print(s.isdigit())   # False (contains letters)
print(s.isalnum())   # True (letters + numbers)
print(" ".isspace()) # True
# Out:
# False
# False
# True
# True

# %%
3. Searching and Replacing

# %%
s = "I like Python and also Java"
print(s.find("like"))     # 2 (index where found)
print(s.replace("Python", "Java"))  # I love Java
# Out:
# 2
# I like Java and also Java

# %%
4. Splitting and Joining

# %%
s = "apple,banana,cherry"
fruits = s.split(",")    # ['apple', 'banana', 'cherry']
print(fruits)

joined = "-".join(fruits)
print(joined)  # apple-banana-cherry
# Out:
# ['apple', 'banana', 'cherry']
# apple-banana-cherry

# %% [markdown]
# ### 3. String Formatting

# %%
1. Using f-strings:

# %%
name = "Alice"
age = 22
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Alice and I am 22 years old.

# %%
pi = 3.14159
print(f"Value of pi is {pi:.2f}")
# Out:
# Value of pi is 3.14

# %%
2. Using format():

# %%
name = "Alice"
age = 22
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is Alice and I am 22 years old.

# %% [markdown]
# ### 4. String Iteration

# %%
word = "PYTHON"
for ch in word:
    print(ch, end=" ")   # P Y T H O N
# Out:
# P Y T H O N

# %% [markdown]
# ## Programs on Strings

# %%
1. Check if a String is Palindrome

# %%
text = input("Enter a string: ")

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter a string: madam
# Palindrome

# %%
2. Count Words in a String

# %%
s = input("Enter a sentence: ")
words = s.split()
print("Number of words:", len(words))
# Out:
# Enter a sentence: my name is Janu
# Number of words: 4

# %%
3. Check if a String Contains Only Digits

# %%
s = input("Enter a string: ")

if s.isdigit():
    print("String contains only digits")
else:
    print("String has non-digit characters")
# Out:
# Enter a string: 344vk
# String has non-digit characters

# %%
4. Find the Longest Word in a Sentence

# %%
s = input("Enter a sentence: ")
words = s.split()
longest = max(words, key=len)
print("Longest word:", longest)
# Out:
# Enter a sentence: Students are interested to learn Python
# Longest word: interested

# %%
5. Count Vowels and Consonants

# %%
s = input("Enter a string: ").lower()
vowels = "aeiou"
v_count = 0
c_count = 0

for ch in s:
    if ch.isalpha():
        if ch in vowels:
            v_count += 1
        else:
            c_count += 1

print("Vowels:", v_count)
print("Consonants:", c_count)
# Out:
# Enter a string: Sanjana
# Vowels: 3
# Consonants: 4

# %%
6. Program to replace all spaces in a string with '-'

# %%
text = input("Enter a string: ")

new_text = text.replace(" ", "-")

print("Modified string:", new_text)
# Out:
# Enter a string: This is Python Programming class
# Modified string: This-is-Python-Programming-class

# %%
7. Program to count words in a string without using split()

# %%
text = input("Enter a string: ")

count = 0
in_word = True

for char in text:
    if char != " " and in_word:
        count += 1
        in_word = False
    elif char == " ":
        in_word = True

print("Number of words:", count)
# Out:
# Enter a string: Python programming for ECE
# Number of words: 4
