# %% [markdown]
# ## 1. Data Processing Script

# %%
A small data processor that:

 - Reads a list of numbers
 - Cleans the data (removes invalid entries)
 - Performs analysis (mean, max, min, sum)
 - Provides results

# %%
class DataProcessor:
    def __init__(self, data):
        self.data = data

    def clean_data(self):
        self.data = [x for x in self.data if type(x) in (int, float)]
        
    def summary(self):
        total = sum(self.data)
        avg = total / len(self.data)
        return total, avg
    
data = [10, 20, "abc", 30, None, 40]

obj = DataProcessor(data)
obj.clean_data()

print("Cleaned Data:", obj.data)
print("Summary:", obj.summary())
# Out:
# Cleaned Data: [10, 20, 30, 40]
# Summary: (100, 25.0)

# %% [markdown]
# ## 2. Basic Calculator

# %%
class Calculator:
    def add(self, a, b): return a + b
    def sub(self, a, b): return a - b
    def mul(self, a, b): return a * b
    def div(self, a, b): return a / b if b != 0 else "Error: Division by zero"

calc = Calculator()
print(calc.add(10, 5))
print(calc.sub(10, 5))
print(calc.mul(10, 5))
print(calc.div(10, 0))

# %%
class Calculator:
    def __init__(self):
        print("Calculator Ready!")

    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b == 0:
            return "Error! Division by zero."
        return a / b

    def power(self, a, b):
        return a ** b

calc = Calculator()   # Object creation

print("Addition (10 + 5):", calc.add(10, 5))
print("Subtraction (10 - 5):", calc.subtract(10, 5))
print("Multiplication (10 * 5):", calc.multiply(10, 5))
print("Division (10 / 5):", calc.divide(10, 5))
print("Power (2^3):", calc.power(2, 3))
# Out:
# Calculator Ready!
# Addition (10 + 5): 15
# Subtraction (10 - 5): 5
# Multiplication (10 * 5): 50
# Division (10 / 5): 2.0
# Power (2^3): 8

# %% [markdown]
# ## 3. File Organizer

# %%
import os
import shutil

class FileOrganizer:
    def __init__(self, path):
        self.path = path

    def organize(self):
        for file in os.listdir(self.path):
            if file.endswith(".jpg") or file.endswith(".png"):
                folder = "Images"
            elif file.endswith(".pdf") or file.endswith(".txt"):
                folder = "Documents"
            else:
                folder = "Others"

            folder_path = os.path.join(self.path, folder)

            if not os.path.exists(folder_path):
                os.mkdir(folder_path)

            shutil.move(os.path.join(self.path, file), folder_path)

path = input("Enter folder path: ")
obj = FileOrganizer(path)
obj.organize()
print("Files Organized!")
# Out:
# Enter folder path: files
# Files Organized!

# %%
Elaborated version of File organizer

# %%
import os
import shutil

class FileOrganizer:
    def __init__(self, directory):
        self.directory = directory

        # File type categories
        self.file_types = {
            "Images": [".jpg", ".jpeg", ".png", ".gif"],
            "Documents": [".pdf", ".docx", ".txt", ".pptx"],
            "Videos": [".mp4", ".mkv", ".avi"],
            "Music": [".mp3", ".wav"],
            "Programs": [".py", ".java", ".c", ".cpp"]
        }

    def create_folder(self, folder_name):
        path = os.path.join(self.directory, folder_name)
        if not os.path.exists(path):
            os.makedirs(path)

    def move_file(self, file, folder_name):
        source = os.path.join(self.directory, file)
        destination = os.path.join(self.directory, folder_name, file)
        shutil.move(source, destination)

    def organize_files(self):
        for file in os.listdir(self.directory):
            file_path = os.path.join(self.directory, file)

            # Skip directories
            if os.path.isdir(file_path):
                continue

            moved = False
            for folder, extensions in self.file_types.items():
                if file.lower().endswith(tuple(extensions)):
                    self.create_folder(folder)
                    self.move_file(file, folder)
                    moved = True
                    break

            # If file type not matched
            if not moved:
                self.create_folder("Others")
                self.move_file(file, "Others")

folder_path = input("Enter folder path to organize: ")
organizer = FileOrganizer(folder_path)
organizer.organize_files()
print("Files organized successfully!")

# %% [markdown]
# ## 4. Simple Data Analysis with Pandas

# %%
import pandas as pd

# Sample dataset (dictionary → DataFrame)
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [25, 30, 35, 40, 28],
    "Score": [85, 90, 88, 76, 95]
}

df = pd.DataFrame(data)

# 1. Display first few rows
print("Data:\n", df.head())

# 2. Basic statistics
print("\nSummary Statistics:\n", df.describe())

# 3. Average age and score
print("\nAverage Age:", df["Age"].mean())
print("Average Score:", df["Score"].mean())

# 4. Find highest score
topper = df.loc[df["Score"].idxmax()]
print("\nTop Scorer:\n", topper)

# 5. Filter students with score > 85
print("\nStudents with Score > 85:\n", df[df["Score"] > 85])
# Out:
# Data:
#        Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     88
# 3    David   40     76
# 4      Eva   28     95
#
# Summary Statistics:
#              Age      Score
# count   5.00000   5.000000
# mean   31.60000  86.800000
# std     5.94138   7.049823
# min    25.00000  76.000000
# 25%    28.00000  85.000000
# 50%    30.00000  88.000000
# 75%    35.00000  90.000000
# max    40.00000  95.000000
#
# Average Age: 31.6
# Average Score: 86.8
#
# Top Scorer:
#  Name     Eva
# Age       28
# Score     95
# Name: 4, dtype: object
#
# Students with Score > 85:
#        Name  Age  Score
# 1      Bob   30     90
# 2  Charlie   35     88
# 4      Eva   28     95

# %%
Elaborated version of above program

# %%
import pandas as pd

# Dataset
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank"],
    "Age": [25, 30, 35, 40, 28, 32],
    "Score": [85, 90, 88, 76, 95, 80],
    "Department": ["CS", "IT", "CS", "ECE", "IT", "CS"]
}
df = pd.DataFrame(data)

print("==== Original DataFrame ====")
print(df)

# ------------------- 1 MARK QUESTIONS -------------------
print("\n1 MARK ANSWERS:")

# 1. First 3 rows
print("\nQ1: First 3 rows:\n", df.head(3))

# 2. Number of rows and columns
print("\nQ2: Shape (rows, cols):", df.shape)

# 3. Only Name column
print("\nQ3: Name column:\n", df["Name"])

# 4. Maximum Score
print("\nQ4: Maximum Score:", df["Score"].max())

# 5. Unique Departments
print("\nQ5: Unique Departments:", df["Department"].unique())

# ------------------- 2 MARK QUESTIONS -------------------
print("\n2 MARK ANSWERS:")

# 1. Students from IT department
print("\nQ1: Students from IT dept:\n", df[df["Department"] == "IT"])

# 2. Sort by Age
print("\nQ2: Sorted by Age:\n", df.sort_values("Age"))

# 3. Student with minimum Score
print("\nQ3: Student with min Score:\n", df[df["Score"] == df["Score"].min()])

# 4. Average Age
print("\nQ4: Average Age:", df["Age"].mean())

# 5. Count of CS students
print("\nQ5: Number of CS students:", (df["Department"] == "CS").sum())

# ------------------- 5 MARK QUESTIONS -------------------
print("\n5 MARK ANSWERS:")

# 1. Average Score by Department
print("\nQ1: Avg Score by Dept:\n", df.groupby("Department")["Score"].mean())

# 2. Add Result column (Pass/Fail)
df["Result"] = df["Score"].apply(lambda x: "Pass" if x >= 85 else "Fail")
print("\nQ2: Added Result column:\n", df)

# 3. Students older than 30 and Score > 85
print("\nQ3: Students Age > 30 and Score > 85:\n", df[(df["Age"] > 30) & (df["Score"] > 85)])

# 4. Replace ECE with Electronics
df["Department"] = df["Department"].replace("ECE", "Electronics")
print("\nQ4: After replacing ECE with Electronics:\n", df)

# 5. Save and Reload CSV
df.to_csv("students.csv", index=False)
new_df = pd.read_csv("students.csv")
print("\nQ5: Reloaded DataFrame from CSV:\n", new_df)
# Out:
# ==== Original DataFrame ====
#       Name  Age  Score Department
# 0    Alice   25     85         CS
# 1      Bob   30     90         IT
# 2  Charlie   35     88         CS
# 3    David   40     76        ECE
# 4      Eva   28     95         IT
# 5    Frank   32     80         CS
#
# 1 MARK ANSWERS:
#
# Q1: First 3 rows:
#        Name  Age  Score Department
# 0    Alice   25     85         CS
# 1      Bob   30     90         IT
# 2  Charlie   35     88         CS
#
# Q2: Shape (rows, cols): (6, 4)
#
# Q3: Name column:
#  0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# Name: Name, dtype: object
#
# Q4: Maximum Score: 95
#
# Q5: Unique Departments: ['CS' 'IT' 'ECE']
#
# 2 MARK ANSWERS:
#
# Q1: Students from IT dept:
#    Name  Age  Score Department
# 1  Bob   30     90         IT
# 4  Eva   28     95         IT
#
# Q2: Sorted by Age:
#        Name  Age  Score Department
# 0    Alice   25     85         CS
# 4      Eva   28     95         IT
# 1      Bob   30     90         IT
# 5    Frank   32     80         CS
# 2  Charlie   35     88         CS
# 3    David   40     76        ECE
#
# Q3: Student with min Score:
#      Name  Age  Score Department
# 3  David   40     76        ECE
#
# Q4: Average Age: 31.666666666666668
#
# Q5: Number of CS students: 3
#
# 5 MARK ANSWERS:
#
# Q1: Avg Score by Dept:
#  Department
# CS     84.333333
# ECE    76.000000
# IT     92.500000
# Name: Score, dtype: float64
#
# Q2: Added Result column:
#        Name  Age  Score Department Result
# 0    Alice   25     85         CS   Pass
# 1      Bob   30     90         IT   Pass
# 2  Charlie   35     88         CS   Pass
# 3    David   40     76        ECE   Fail
# 4      Eva   28     95         IT   Pass
# 5    Frank   32     80         CS   Fail
#
# Q3: Students Age > 30 and Score > 85:
#        Name  Age  Score Department Result
# 2  Charlie   35     88         CS   Pass
#
# Q4: After replacing ECE with Electronics:
#        Name  Age  Score   Department Result
# 0    Alice   25     85           CS   Pass
# 1      Bob   30     90           IT   Pass
# 2  Charlie   35     88           CS   Pass
# 3    David   40     76  Electronics   Fail
# 4      Eva   28     95           IT   Pass
# 5    Frank   32     80           CS   Fail
#
# Q5: Reloaded DataFrame from CSV:
#        Name  Age  Score   Department Result
# 0    Alice   25     85           CS   Pass
# 1      Bob   30     90           IT   Pass
# 2  Charlie   35     88           CS   Pass
# 3    David   40     76  Electronics   Fail
# 4      Eva   28     95           IT   Pass
# 5    Frank   32     80           CS   Fail
