# %% [markdown]
# ## 1. Encapsulation

# %% [raw]
# Encapsulation means wrapping data (attributes) and methods (functions) into a single unit (class).
#
# It restricts direct access to some variables and methods, protecting the internal state of an object.
#
# Achieved in Python using access modifiers.

# %% [markdown]
# ### Access Modifiers in Python
#
# Unlike languages like Java or C++, Python does not have strict access control keywords. Instead, it uses convention and name mangling:

# %% [raw]
# 1. Public members (default)-> Accessible from anywhere.
#          Example: self.name
#
# 2. Protected members (_single underscore)
# A convention: should not be accessed directly outside the class.
#          Example: self._salary
#
# 3. Private members (__double underscore)
# Name mangled → can’t be accessed directly outside the class.
#          Example: self.__password

# %% [raw]
# Why Encapsulation?
#
# ✅ Data protection (prevent accidental changes).
# ✅ Controlled access (via getters/setters).
# ✅ Flexibility (internal logic can be changed without affecting external code).
# ✅ Code maintenance and readability.

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name            # Public
        self._marks = marks         # Protected
        self.__grade = "A"          # Private

    def display(self):
        print(f"Name: {self.name}, Marks: {self._marks}, Grade: {self.__grade}")

s = Student("Anu", 90)
s.display()

print(s.name)       # ✅ Public accessible
print(s._marks)     # ⚠️ Accessible but not recommended
print(s.__grade)  # ❌ Error: private
# Out:
# Name: Anu, Marks: 90, Grade: A
# Anu
# 90
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <module>
#      13 print(s.name)       # ✅ Public accessible
#      14 print(s._marks)     # ⚠️ Accessible but not recommended
# ---> 15 print(s.__grade)
#
# AttributeError: 'Student' object has no attribute '__grade'

# %%
To Access Private Members (Name Mangling)

# %%
print(s._Student__grade)   # ✅ Accessing private variable
# Out:
# A

# %% [markdown]
# ## 2. Polymorphism:
#
# It allows different classes to define methods with the same name but different behaviors.
#
# "One name, many forms."
#
# Same method name behaves differently depending on context.

# %%
print(len("abc"))
print(len([1,2,3]))
# Out:
# 3
# 3

# %% [raw]
# Why Polymorphism?
#
# ✅ Improves code flexibility and reusability
#
# ✅ Makes code easier to maintain and extend
#
# ✅ Reduces duplication of logic

# %% [markdown]
# ### Types of Polymorphism:

# %% [raw]
# 1. Method Overriding: A subclass provides its own implementation of a method already defined in its parent class.
#
# 2. Method Overloading: Same method name with different parameters.
#
# 3. Operator Overloading: Same operator behaves differently depending on the operands.

# %% [markdown]
# ### 1. Method Overriding:
#
# If the same method is present in both the superclass and subclass
#
# In this case, the method in the subclass overrides the method in the superclass. This concept is known as method overriding in Python.

# %%
Ex1: Overriding method

# %%
class Parent:    # Superclass
    def display(self):
        print("Display from Parent")

class Child(Parent):   # Subclass
    def display(self):    # Overriding
        print("Display from Child")

c = Child()  # Object creation
c.display()
# Out:
# Display from Child

# %% [raw]
# How to overcome Overriding:
#
# 1. Use super() to call parent’s method inside child
# 2. Call Parent’s method directly (avoiding super)

# %%
class Parent:    # Superclass
    def display(self):
        print("Display from Parent")

class Child(Parent):   # Subclass
    def display(self):    # Overriding
#         super().display()   
        Parent.display(self)
        print("Display from Child")

c = Child()  # Object creation
c.display()
# Out:
# Display from Parent
# Display from Child

# %%
Ex2: Overriding method

# %%
class Shape:
    def area(self):
        print("Area not defined")

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
#         super().area()
        Shape.area(self)
        print(3.14 * self.r * self.r)        
        
class Square(Shape):
    def __init__(self, s):
        self.s = s
    def area(self):
#         super().area()
        Shape.area(self)
        print(self.s * self.s)        
        
c = Circle(5)   # Object creation
c.area()

d = Square(4)   # Object creation
d.area()
# Out:
# Area not defined
# 78.5
# Area not defined
# 16

# %% [markdown]
# ### 2. Method Overloading:
#
# Python does not support method overloading directly (same method name with different parameters).

# %% [raw]
# Ex1: Overloading with different parameters
# Sol: Using default arguments or *args.

# %%
class Calculator:
    def add(self, a=0, b=0, c=0):
        return a + b + c

c = Calculator()
print(c.add(2, 3))       # 5
print(c.add(2, 3, 4))    # 9
print(c.add(5))          # 5
# Out:
# 5
# 9
# 5

# %% [raw]
# Eg2: Overloading with Different Data Types
# Sol: Using Type checking (isinstance)

# %%
class Display:
    def show(self, value):
        if isinstance(value, int):
            print("Integer:", value)
        elif isinstance(value, str):
            print("String:", value)
        else:
            print("Unknown type:", value)

d = Display()
d.show(10)          # Integer: 10
d.show("Python")    # String: Python
d.show(10.7)
d.show([1, 2, 3])   # Unknown type: [1, 2, 3]
# Out:
# Integer: 10
# String: Python
# Unknown type: 10.7
# Unknown type: [1, 2, 3]

# %% [markdown]
# ### 3. Operator Overloading:
#
# Same operator behaves differently depending on the operands.

# %% [raw]
# Eg:1 The same operator can be used for both bitwise operations and logical operations, depending on the context.

# %%
# Bitwise AND
print(5 & 3)  # Output: 1 (binary: 0101 & 0011)

# Logical AND
print(True & False)  # Output: False
# Out:
# 1
# False

# %% [raw]
# Eg:2 Operators might perform differently based on the data types they are working with.

# %%
# Addition for integers
print(1 + 2)  

# Concatenation for strings
print("Hello" + " " + "World")  # Output: Hello World

# %% [markdown]
# ### Examples of Class Polymorphism:

# %%
class Tomato(): 
     def type(self): 
       print("Vegetable") 
     def color(self):
       print("Red") 
class Apple(): 
     def type(self): 
       print("Fruit") 
     def color(self): 
       print("Green") 
      
def func(obj): 
    obj.type() 
    obj.color()
        
obj_tomato = Tomato() 
obj_apple = Apple() 
func(obj_tomato) 
func(obj_apple)
# Out:
# Vegetable
# Red
# Fruit
# Green

# %%
class India():
     def capital(self):
        print("New Delhi")
 
     def language(self):
        print("Hindi and English")

class USA():
     def capital(self):
        print("Washington, D.C.")
 
     def language(self):
        print("English")

obj_ind = India()
obj_usa = USA()
for country in (obj_ind, obj_usa):
    country.capital()
    country.language()
# Out:
# New Delhi
# Hindi and English
# Washington, D.C.
# English
