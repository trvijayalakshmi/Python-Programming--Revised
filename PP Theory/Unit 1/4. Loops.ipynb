# %% [markdown]
# ### Python Loops
#
# Python has two primitive loop commands:
#
# a) for loops
# b) while loops

# %% [markdown]
# ### a) The for loop

# %%
for i in range(8):
    print(i, end = ' ')
# Out:
# 0 1 2 3 4 5 6 7

# %%
for i in range(2,8):
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(2,10,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
for i in range(7,2,-1):
    print(i)
# Out:
# 7
# 6
# 5
# 4
# 3

# %%
Difference between Continue and break statements:

# %%
for i in range(1,10):
    if i == 4:
        break
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(1,10):
    if i == 4:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9

# %%
Purpose of else clause for loop:

# %%
for i in range(1,5):  
    print(i)
else:
    print("end of for loop")
# Out:
# 1
# 2
# 3
# 4
# end of for loop

# %%
for i in range(1,3):  # try changing 3 to 5
    if i == 3:
        break
    print(i)
else:
    print("end of for loop")
# Out:
# 1
# 2
# end of for loop

# %%
for i in range(1,5):  
    if i == 3:
        continue
    print(i)
else:
    print("not in for loop")
# Out:
# 1
# 2
# 4
# not in for loop

# %%
The pass statement:

# %%
# Using pass statement in an empty loop
for i in range(5):
    pass   # Loop runs but does nothing
print("Loop finished!")
# Out:
# Loop finished!

# %%
else clause with for loop:

# %%
for i in range(1, 6):
    if i == 3:
        pass   # Do nothing when i = 3
    else:
        print(i)
else:
    print('end of for loop')
# Out:
# 1
# 2
# 4
# 5
# end of for loop

# %%
for loop without range function:

# %%
x = [30, 25, 12, 32]
for i in x:
    print(i)
# Out:
# 30
# 25
# 12
# 32

# %%
x = [30, 25, 12, 32]
for i in range(len(x)):
    print(x[i])
# Out:
# 30
# 25
# 12
# 32

# %%
x = "python"
for i in x:
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
x = "python"
for i in range(len(x)):
    print(x[i])
# Out:
# p
# y
# t
# h
# o
# n

# %%
x = ["python", "C", "Java", "C++", "GO"]
for i in x:
    print(i)
# Out:
# python
# C
# Java
# C++
# GO

# %%
x = ["python", "C", "Java", "C++", "GO"]
for i in range(len(x)):
    print(x[i])
# Out:
# python
# C
# Java
# C++
# GO

# %% [markdown]
# ### b) The while Loop
# With the while loop we can execute a set of statements as long as a condition is true.

# %%
The while loop requires relevant variables to be ready, 
in this example we need to define an indexing variable, i, 
which we set to 1.

# %%
#Print i as long as i is less than 6:

i = 1
while i < 6:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
The else Statement

With the else statement we can run a block of code once when 
the condition no longer is true:

# %%
#Print a message once the condition is false:

i = 1
while i < 6:
    print(i)
    i += 1
else:
    print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
The break Statement

With the break statement we can stop the loop even 
if the while condition is true:

# %%
# Exit the loop when i is 3:  Change 2 to 5

i = 0
while i < 2:
    i += 1
    if i == 3:
        break
    print(i)  
else:
    print("condition in while loop is false")
# Out:
# 1
# 2
# condition in while loop is false

# %%
The continue Statement

With the continue statement we can stop the current iteration,
and continue with the next:

# %%
#Continue to the next iteration if i is 3:

i = 0
while i < 6:
    i += 1
    if i == 3:
        continue
    print(i)
else:
    print("not in while loop")
# Out:
# 1
# 2
# 4
# 5
# 6
# not in while loop

# %%
The pass statement

# %%
i = 1
while i <= 3:
    pass
    i += 1

print("Loop finished!")
# Out:
# Loop finished!

# %%
Example of Nested for loop:

# %%
# Right-angle triangle pattern
for i in range(1, 6):       # Outer loop controls rows
    for j in range(i):      # Inner loop prints stars in each row
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# ## Programs using for and while loops

# %%
1) Print the below triangle using for loop.

5
4 4
3 3 3
2 2 2 2
1 1 1 1 1

# %%
for i in range(5, 0, -1):  # Iterate from 5 to 1 in reverse order
    for j in range(i,6):    # Repeat the current number i times
        print(i, end=" ") # Print the current number followed by a space
    print()
# Out:
# 5
# 4 4
# 3 3 3
# 2 2 2 2
# 1 1 1 1 1

# %%
2) Print the below triangle using for loop.

5 5 5 5 5
4 4 4 4
3 3 3
2 2 
1

# %%
for i in range(5, 0, -1):  
    for j in range(i):   
        print(i, end=" ") 
    print()
# Out:
# 5 5 5 5 5
# 4 4 4 4
# 3 3 3
# 2 2
# 1

# %%
for i in range(1,6):
    print("*"*i, end=" ")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
p = 69
for i in range(5, 0, -1):  
    for j in range(i):   
        print(chr(p), end=" ") 
    print()
    p -= 1
# Out:
# E E E E E
# D D D D
# C C C
# B B
# A

# %%
p = 65
for i in range(1,6):  
    for j in range(i):   
        print(chr(p), end=" ") 
    print()
    p += 1
# Out:
# A
# B B
# C C C
# D D D D
# E E E E E

# %%
3. Python program to print all prime numbers in an interval

# %%
s = 6
e = 30
for i in range(s, e):
    if i == 0 or i == 1:
        continue
    else:
        for j in range(2, int(i/2)+1):
            if i % j == 0:
                break
        else:
            print(i,end = " ")
# Out:
# 7 11 13 17 19 23 29

# %%
4. Program to print the Fibonacci sequence using for and while loop

# %%
n = int(input("Enter n: "))
a, b = 0, 1
print("Fibonacci Series:", end=" ")
for i in range(n):
    print(a, end=" ")
    a, b = b, a+b
# Out:
# Enter N: 8
# Fibonacci Series: 0 1 1 2 3 5 8 13

# %%
n = int(input("Enter n: "))
a, b = 0, 1
count = 0
while count < n:
    print(a, end=" ")
    a, b = b, a + b
    count += 1
# Out:
# Enter n: 6
# 0 1 1 2 3 5

# %%
5. Python program to find the gcd of the given numbers

# %%
a = 64
b = 4
print(f"The gcd of {a} and {b} is", end=" ")
while b:
    a, b = b, a % b
print(a)
# Out:
# The gcd of 64 and 4 is 4

# %%
6. Sum of first 10 natural numbers

# %%
total = 0
for i in range(1, 11):
    total += i
print("Sum of first 10 numbers is:", total)
# Out:
# Sum of first 10 numbers is: 55

# %%
7. Multiplication Table of a Number

# %%
num = int(input("Enter a number: "))
for i in range(1, 11):
    print(f"{num} x {i} = {num*i}")
# Out:
# Enter a number: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
8. Factorial of a number

# %%
num = int(input("Enter a number: "))
fact = 1
i = 1
while i <= num:
    fact *= i
    i += 1
print("Factorial is:", fact)
# Out:
# Enter a number: 6
# Factorial is: 720

# %%
9. Reverse the digits of a number

# %%
num = int(input("Enter a number: "))
rev = 0
while num > 0:
    digit = num % 10
    rev = rev * 10 + digit
    num //= 10
print("Reversed number is:", rev)
# Out:
# Enter a number: 5467
# Reversed number is: 7645

# %%
10. Reverse a string

# %%
text = input("Enter a string: ")
rev = ""
for ch in text:
    rev = ch + rev
print("Reversed String:", rev)
# Out:
# Enter a string: sanjana
# Reversed String: anajnas

# %%
11. Print prime numbers up to N using while and for loop

# %%
# Prime numbers up to N using while and for loop
N = int(input("Enter a number N: "))

num = 2  # first prime number
while num <= N:   # while loop checks all numbers up to N
    is_prime = True
    for i in range(2, num):   # for loop checks divisibility
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num, end=" ")
    num += 1
# Out:
# Enter a number N: 15
# 2 3 5 7 11 13

# %%
12. Print Even and Odd numbers

# %%
N = int(input("Enter N: "))

i = 1
print("Even numbers: ", end = " ")
while i <= N:
    if i % 2 == 0:
        print(i, end =" ")
    i += 1

i = 1
print("\nOdd numbers: ", end = " ")
while i <= N:
    if i % 2 != 0:
        print(i, end =" ")
    i += 1
# Out:
# Enter N: 9
# Even numbers:  2 4 6 8
# Odd numbers:  1 3 5 7 9

# %%
13. Sum of Even and Odd Numbers Separately (1 to N)

# %%
N = int(input("Enter N: "))
even_sum, odd_sum = 0, 0
i = 1
while i <= N:
    if i % 2 == 0:
        even_sum += i
    else:
        odd_sum += i
    i += 1
print("Sum of Even numbers:", even_sum)
print("Sum of Odd numbers:", odd_sum)
# Out:
# Enter N: 12
# Sum of Even numbers: 42
# Sum of Odd numbers: 36

# %%
14. Searching a number in a list

# %%
numbers = [3, 8, 15, 22, 7, 10]

for n in numbers:
    if n == 7:
        print("Number 7 found! Stopping search.")
        break
    print("Checking:", n)
# Out:
# Checking: 3
# Checking: 8
# Checking: 15
# Checking: 22
# Number 7 found! Stopping search.
