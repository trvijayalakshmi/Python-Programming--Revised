# %% [markdown]
# # 1. Comments

# %%
# Multiline strings

a = """Pollution is the introduction of harmful
     materials into the environment. 
     These harmful materials are called pollutants."""
print(a)

# %%
# Three single quotes

a = '''Pollution is the introduction of harmful
     materials into the environment. 
     These harmful materials are called pollutants.'''
print(a)

# %% [markdown]
# # 2. Numeric Data Types

# %% [markdown]
# There are three numeric types in Python:
#
# int
# float
# complex
# Variables of numeric types are created when you assign a value to them:

# %%
x = 1    # int
y = 2.8  # float
z = 4+3j   # complex

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# a) Integers

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# b) Floating Point Numbers

# %%
x = 35e3
y = 12E4
z = -87.7e-100

print(type(x))
print(type(y))
print(type(z))
print(y)
print(x)
print(z)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# 120000.0
# 35000.0
# -8.77e-99

# %% [markdown]
# c) Complex numbers

# %%
# Creating complex numbers
import numpy as np
z1 = 3 + 4j
z2 = 2 - 5j

print("z1 =", z1)
print("z2 =", z2)
print(np.real(z1))
# Out:
# z1 = (3+4j)
# z2 = (2-5j)
# 3.0

# %% [markdown]
# # 3. Type Casting

# %%
    • Implicit Type Casting → Done automatically by Python.
    • Explicit Type Casting → Done manually by the programmer
       using built-in functions.

# %%
In Implicit type conversion, the Python interpreter automatically 
converts one data type to another without any user involvement.

In Explicit type conversion, the data type is manually changed by 
the user as per their requirement. With explicit type conversion, 
there is a risk of data loss since we are forcing an expression to 
be changed in some specific data type.

# %% [markdown]
# #### 1. Implicit Type Conversion

# %%
x = 10     # int
y = 3.5    # float
z = x + y  # int + float → float
print(z)   # 13.5
print(type(z))  # <class 'float'>
# Out:
# 13.5
# <class 'float'>

# %% [markdown]
# #### 2. Explicit Type casting

# %%
# Converting floating point to integer
x = int(3.14)
print(x) 
print(type(x))
# Out:
# 3
# <class 'int'>

# %%
# Converting string to floating point
x = float("3.14")
print(x) 
print(type(x))
# Out:
# 3.14
# <class 'float'>

# %%
# Converting integer to string
x = str(123)
print(x)
print(type(x))
# Out:
# 123
# <class 'str'>

# %%
x = int("45")
print(type(x))
# Out:
# <class 'int'>

# %%
# Converts a value to a boolean
x = bool(0)
print(x)
print(type(x))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# # 4. Operators

# %% [markdown]
# 1. Arithmetic Operators
# 2. Relational Operators
# 3. Logical Operators
# 4. Assignment Operators
# 5. Membership Operators
# 6. Identity Operators
# 7. Bitwise Operators

# %%
Arithmetic operators are used to perform mathematical operations 
like addition, subtraction, multiplication and division.

There are 7 arithmetic operators in Python:

Addition
Subtraction
Multiplication
Division
Modulus
Exponentiation
Floor division

# %%
# 1. Arithmetic Operators

x = -10
y = 4
result = x + y * 2 
print(result)

z1 = x //y
z2 = x /y
print(z1)
print(z2)
# Out:
# -2
# -3
# -2.5

# %%
# 2. Relational Operators

a, b = 10, 20
print("a > b :", a > b)     # False
print("a < b :", a < b)     # True
# Out:
# a > b : False
# a < b : True

# %%
x, y = 15, 15
print("x == y :", x == y)   # True
print("x != y :", x != y)   # False
# Out:
# x == y : True
# x != y : False

# %%
# 3. Logical Operators

x, y = 10, 0
print("x and y:", x and y)   # 0 (returns y since x is truthy)
print("x or y:", x or y)     # 10 (returns first truthy value)
# Out:
# x and y: 0
# x or y: 10

# %%
a, b = True, False
print("a and b:", a and b)   # False
print("a or b:", a or b)     # True
print("not a:", not a)       # False
# Out:
# a and b: False
# a or b: True
# not a: False

# %%
# Example combining all logical operators
x = 15

if (x > 10 and x < 20) and not (x == 15):
    print("Condition is True")
else:
    print("Condition is False")
# Out:
# Condition is False

# %%
4. Assignment Operators

# %%
With examples illustrate augmented assignment and multiple
assignment operators (Old question)

# %%
Augmented assignment

# %%
# 4. Assignment operators

x = 20
x /= 5   # same as x = x / 5
print("Result", x)
# Out:
# Result 4.0

# %%
Multiple assignment

# %%
# Assigning multiple variables in one line
a, b, c = 10, 20, 30
print("a =", a, "b =", b, "c =", c)   # a = 10 b = 20 c = 30

# Swapping two variables (no need of temp variable)
x, y = 5, 7
x, y = y, x
print("After swapping: x =", x, "y =", y)   # x = 7 y = 5

# Assigning same value to multiple variables
p = q = r = 50
print("p =", p, "q =", q, "r =", r)   # p = 50 q = 50 r = 50
# Out:
# a = 10 b = 20 c = 30
# After swapping: x = 7 y = 5
# p = 50 q = 50 r = 50

# %%
x = 17
x %= 5 
print("Result", x)
# Out:
# Result 2

# %%
# 5. Membership operators

x = [[1, 2], [3, 4]]
print(3 in x)  # Output: True
print(6 not in x)  # Output: True

y = [3, 4]
print(y in x)
# Out:
# False
# True
# True

# %%
# 6. Identity operators

x = [1, 2, 3]
y = [1, 2, 3]

print(x == y)   # True → contents are the same
print(x is y)   # False → stored at different memory locations
print(x is not y)

z = 4
w = 4
print(z is w)
# Out:
# True
# False
# True
# True

# %%
# 7. Bit-wise operators

a = 12  # 1100
b = 6   # 0110

print("a & b =", a & b)   # 0100 → 4     (a and b)
print("a | b =", a | b)   # 1110 → 14     (a or b)
print("a ^ b =", a ^ b)   # 1010 → 10     (a xor b)
a = 20
print("a << 2 =", a << 3) # 110000 → 48   (Left shift)
print("a >> 2 =", a >> 2) # 0011 → 3    (Right shift)
# Out:
# a & b = 4
# a | b = 14
# a ^ b = 10
# a << 2 = 160
# a >> 2 = 5

# %% [markdown]
# # 5. Input and Output functions

# %% [markdown]
# a) Input function

# %%
name = input("Enter your name: ") # string input
print("My name is ",name)

print("Hello, " + name + "!")
# Out:
# Enter your name: 123
# My name is  123
# Hello, 123!

# %%
x = int(input("enter the value")) # Try floating point no
print("The value is", x)
# Out:
# enter the value125
# The value is 125

# %% [markdown]
# b) Print function

# %%
# Printing multiple values
x = 10
y = 20
print("x=",x,'\n',"y=",y)
# Out:
# x= 10
#  y= 20

# %%
# Printing with formatting
pi = 3.14159
print("Pi Value is", format(pi, ".2f"))  # Output: "Value: 3.14"
print(f"{pi} is a floating point no.")
print(f"{pi:.2f} is a floating point no.")
# Out:
# Pi Value is 3.14
# 3.14159 is a floating point no.
# 3.14 is a floating point no.

# %%
# Using the end argument to change the end character
print("Hello,", end=" ")
print("world!")  # Output: Hello, world!
# Out:
# Hello, world!
