# %%
1. What is a Package?

A package in Python is a collection of modules (Python files).

It helps organize code in a hierarchical structure.

A package is simply a directory that contains an __init__.py file
 (can be empty).

Packages allow you to reuse code, avoid conflicts, and keep projects well-structured.

# %%
Packages help in organizing large programs into smaller, manageable
modules and provide powerful pre-built functionality 
(e.g., numpy for arrays, pandas for data analysis).

# %%
2. Creating and using a package

# %%
Structure of a Package

For example, suppose we want a package for math utilities:

my_package/
│
├── __init__.py        # Makes this directory a package
├── addition.py        # Module 1
└── multiplication.py  # Module 2

# %%
# Create arithmetic.py file
def add(a, b):
    return a + b
def sub(a, b):
    return a - b
def mul(a, b):
    return a * b
def div(a, b):
    return a / b

# %%
# Create geometry1.py file
def square(a):
    area_s = a*a
    peri_s = 4*a
    return area_s, peri_s
def rectangle(a,b):
    area_r = a*b
    peri_r = 2*(a+b)
    return area_r, peri_r
def triangle(a,b,c):
    area_t = 0.5 * a * b
    peri_t = a + b + c
    return area_t, peri_t

# %%
# Create __init__.py
from arithmetic import *
from geometry1 import *

# %%
3. Using the Package

# %%
# importing from the package
import my_package.arithmetic as m1
import my_package.geometry1 as m2

print("Addition:", m1.add(10, 5))
print("Multiplication:", m1.mul(10, 5))

area_t, peri_t = m2.triangle(4,6,5)
print(f"Area and perimeter of a triangle are: {area_t}, {peri_t}")

area_r, peri_r = m2.rectangle(6,4)
print(f"Area and perimeter of a rectangle are: {area_r}, {peri_r}")

area_s, peri_s = m2.square(10)
print(f"Area and perimeter of a square are: {area_s}, {peri_s}")

# %%
Difference between module, package, and library

Module = Single Python file.

Package = Collection of modules (folder with __init__.py).

Library = Collection of packages.

# %%
5. Installing a Package

Example: Installing NumPy

# %%
pip install numpy
